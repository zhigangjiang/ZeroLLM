# %%
import json

fw = open("/root/projects/happy-llm/ZeroLLM/autodl-tmp/seq_monkey_datawhale_small.jsonl", "w")
i = 0
with open("/root/projects/happy-llm/ZeroLLM/autodl-tmp/seq_monkey_datawhale.jsonl", "r") as f:
    while i < 100000:
        line = f.readline()
        fw.write(line)
        i += 1
fw.close()
